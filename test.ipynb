# %% [markdown]
# 这是一个测试文件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 首先进入我的仓库，master表示在当前的主分支

# %% [markdown]
# 然后上传此文件

# %%
git add test.ipynb
git commit -m my first test

# %% [markdown]
# 然后推送到远程仓库，这里之前已经建立好了ssh连接

# %%
git push -u origin master
