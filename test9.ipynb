# %% [markdown]
# 1.开始学习matplotlib

# %%
# %matplotlib inline
#用matplotlib notebook也行
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# 2.创建子图

# %%
fig,axes = plt.subplots(2,2)
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015D4DDA5A90>,
# ...
#       dtype=object)

# %% [markdown]
# 3.标记和线性必须放在颜色后面

# %%
plt.plot(np.random.randn(10),'ko--')

# %% [markdown]
# 4.添加图例，plt.legend()
